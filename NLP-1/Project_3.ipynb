# %%
import nltk
import numpy as np
nltk.download('senseval')
nltk.download('stopwords')
from nltk.corpus import senseval
import random

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from nltk.classify import accuracy, NaiveBayesClassifier, MaxentClassifier
from collections import defaultdict
# Out:
# [nltk_data] Downloading package senseval to /root/nltk_data...
# [nltk_data]   Unzipping corpora/senseval.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def extract_vocabulary_frequency(data, stopwords=[], n=300):
    freq_dist = nltk.FreqDist()
    for instance in data:
        words = [context_word[0] for context_word in instance.context if not context_word[0].startswith(instance.word)]
        for word in set(words) - set(stopwords):
            freq_dist[word] += 1
    return freq_dist.most_common()[:n+1]

# %%
def context_features(instance, vocab, distance=3):
    features = {}
    index = instance.position
    context = instance.context
    for i in range(max(0, index - distance), index):
        features[context[i][0]] = True

    for i in range(index + 1, min(index + distance + 1, len(context))):
        features[context[i][0]] = True

    return features

# %%
def train_naive_bayes(data, stopwords_list, training_data, test_data, unique_labels, vocab_size, window_size):
    vocabulary = [word for word, _ in extract_vocabulary_frequency(data, stopwords=stopwords_list, n=vocab_size)]
    label_distribution = {label: [instance[1] for instance in training_data].count(label) / len(training_data) for label in unique_labels}
    predicted_labels = []
    true_labels = []

    for instance in test_data:
        test_instance = instance[0]
        true_label = instance[1]
        features = context_features(test_instance, vocabulary, window_size)
        probabilities = []

        for label in unique_labels:
            feature_occurrence = {word: 0 for word in vocabulary}
            total_occurrence = {word: 0 for word in vocabulary}

            for train_instance in training_data:
                if label == train_instance[1]:
                    words = context_features(train_instance[0], vocabulary, window_size)
                    for word in words:
                        if word in feature_occurrence:
                            feature_occurrence[word] += 1

            for train_instance in training_data:
                words = context_features(train_instance[0], vocabulary, window_size)
                for word in words:
                    if word in total_occurrence:
                        total_occurrence[word] += 1

            theta = {}
            for feature in feature_occurrence:
                theta[feature] = (1 + feature_occurrence[feature]) / (len(unique_labels) + total_occurrence[feature])

            p_c_s = label_distribution[label]
            for feature in features:
                if feature in theta:
                    p_c_s *= theta[feature]

            probabilities.append(p_c_s)

        predicted_labels.append(unique_labels[np.argmax(probabilities)])
        true_labels.append(true_label)

    return predicted_labels, true_labels

# %%
def validate_parameters(instances, stopwords_list, training_data, validation_data, unique_labels, window_sizes,
                        vocab_sizes):
    best_window_size = 2
    best_vocab_size = 200
    best_accuracy = 0

    print("=== Validation ===")
    print("{:<15} {:<15} {:<20}".format("Window size", "Vocabulary size", "Validation Accuracy"))
    print("=" * 45)

    for window_size in window_sizes:
        for vocab_size in vocab_sizes:
            predicted_labels, true_labels = train_naive_bayes(
                instances,
                stopwords_list,
                training_data,
                validation_data,
                unique_labels,
                vocab_size,
                window_size
            )

            accuracy = accuracy_score(true_labels, predicted_labels)
            print("{:<15} {:<15} {:.4f}".format(window_size, vocab_size, accuracy))

            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_window_size = window_size
                best_vocab_size = vocab_size

    print("\nBest parameters - Window size: {}, Vocabulary size: {}".format(best_window_size, best_vocab_size))
    return best_window_size, best_vocab_size

# %%
def test_model(instances, stopwords_list, training_data, test_data, unique_labels, best_vocab_size, best_window_size):
    print("\n=== Testing ===")
    predicted_labels, true_labels = train_naive_bayes(
        instances,
        stopwords_list,
        training_data,
        test_data,
        unique_labels,
        best_vocab_size,
        best_window_size
    )

    accuracy = accuracy_score(true_labels, predicted_labels)
    print("Accuracy: {:.4f}".format(accuracy))
    print("\nConfusion matrix:")
    print(confusion_matrix(true_labels, predicted_labels))

    examples = 0
    print("\nExamples of errors:")
    print("===================")
    for i in range(len(true_labels)):
        if true_labels[i] != predicted_labels[i]:
            print("Test instance:")
            print(test_data[i][0])
            print("True label: {}, Predicted label: {}".format(true_labels[i], predicted_labels[i]))
            print("-------------------")
            examples += 1
        if examples == 10:
            break

# %%
def model(word):
    senses = []
    instances = []

    for instance in nltk.corpus.senseval.instances(word):
        senses.append((instance, instance.senses[0]))
        instances.append(instance)

    stopwords_list = nltk.corpus.stopwords.words('english')
    unique_labels = list(set([label for (_, label) in senses]))

    random.seed(100)
    random.shuffle(senses)
    n = len(senses)
    training_data = senses[:int(0.7 * n)]
    validation_data = senses[int(0.7 * n):int(0.75 * n)]
    test_data = senses[int(0.75 * n):n]

    window_sizes = [1, 2, 3, 4]
    vocab_sizes = [100, 200, 300]

    best_window_size, best_vocab_size = validate_parameters(
        instances, stopwords_list, training_data, validation_data, unique_labels, window_sizes, vocab_sizes
    )

    test_model(instances, stopwords_list, training_data, test_data, unique_labels, best_vocab_size, best_window_size)

# %%
model('line.pos')
# Out:
# === Validation ===
# Window size     Vocabulary size Validation Accuracy
# =============================================
# 1               100             0.5894
# 1               200             0.5942
# 1               300             0.5990
# 2               100             0.5797
# 2               200             0.5845
# 2               300             0.5942
# 3               100             0.5652
# 3               200             0.5700
# 3               300             0.5749
# 4               100             0.5604
# 4               200             0.5652
# 4               300             0.5749
#
# Best parameters - Window size: 1, Vocabulary size: 300
#
# === Testing ===
# Accuracy: 0.6152
#
# Confusion matrix:
# [[  0   0   1   0  95   0]
#  [  0  15   0   0  72   0]
#  [  0   0  13   0  66   0]
#  [  0   0   0  36  65   0]
#  [  0   0   1   0 570   0]
#  [  0   1   1   0  97   4]]
#
# Examples of errors:
# ===================
# Test instance:
# SensevalInstance(word='line-n', position=28, context=[('overall', 'RB'), ('they', 'PRP'), ('increased', 'VBD'), ('2', 'CD'), ('.', '.'), ('8', 'CD'), ('%', 'NN'), ('to', 'TO'), ('12', 'CD'), ('.', '.'), ('1', 'CD'), ('million', 'CD'), (',', ','), ('putting', 'VBG'), ('u', 'NNP'), ('s', 'NNP'), ('west', 'NNP'), ('over', 'IN'), ('the', 'DT'), ('12', 'CD'), ('million', 'CD'), ('mark', 'NN'), ('for', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('time', 'NN'), ('.', '.'), ('business', 'NN'), ('lines', 'NNS'), ('increased', 'VBN'), ('3', 'CD'), ('.', '.'), ('7', 'CD'), ('%', 'NN'), ('to', 'TO'), ('3', 'CD'), ('.', '.'), ('3', 'CD'), ('million', 'CD'), ('.', '.')], senses=('phone',))
# True label: phone, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=33, context=[('so', 'RB'), ('he', 'PRP'), ('sells', 'VBZ'), ('garlic', 'NN'), ('.', '.'), ('in', 'IN'), ('one', 'CD'), ('of', 'IN'), ('his', 'PRP$'), ('stalls', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('back-alley', 'JJ'), ('market', 'NN'), ('deep', 'JJ'), ('in', 'IN'), ('seoul', 'NNP'), ("'s", 'POS'), ('south', 'JJ'), ('side', 'NN'), ('he', 'PRP'), ('sells', 'VBZ'), ('nothing', 'NN'), ('but', 'CC'), ('garlic', 'NN'), (':', ':'), ('hundreds', 'NNS'), ('of', 'IN'), ('straw', 'NN'), ('"', '"'), ('chops', 'NNS'), ('"', '"'), ('or', 'CC'), ('lines', 'NNS'), ('hang', 'VBP'), ('from', 'IN'), ('the', 'DT'), ('ceiling', 'NN'), (',', ','), ('each', 'DT'), ('chop', 'NN'), ('with', 'IN'), ('100', 'CD'), ('bulbs', 'NNS'), ('of', 'IN'), ('garlic', 'NN'), ('attached', 'VBN'), ('to', 'TO'), ('it', 'PRP'), (',', ','), ('each', 'DT'), ('bulb', 'NN'), ('containing', 'VBG'), ('five', 'CD'), ('to', 'TO'), ('10', 'CD'), ('cloves', 'NNS'), ('.', '.')], senses=('cord',))
# True label: cord, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=25, context=[('freddy', 'NNP'), ('reached', 'VBD'), ('into', 'IN'), ('the', 'DT'), ('box', 'NN'), ('and', 'CC'), ('brought', 'VBN'), ('out', 'RP'), ('a', 'DT'), ('small', 'JJ'), ('fishing', 'NN'), ('rod', 'NN'), ('in', 'IN'), ('three', 'CD'), ('sections', 'NNS'), ('.', '.'), ('he', 'PRP'), ('fitted', 'VBD'), ('two', 'CD'), ('of', 'IN'), ('them', 'PRP'), ('together', 'RB'), (',', ','), ('strung', 'VBD'), ('the', 'DT'), ('line', 'NN'), ('along', 'IN'), ('its', 'PRP$'), ('length', 'NN'), (',', ','), ('and', 'CC'), ('then', 'RB'), (',', ','), ('dropping', 'VBG'), ('the', 'DT'), ('whole', 'JJ'), ('apparatus', 'NN'), ('through', 'IN'), ('the', 'DT'), ('open', 'JJ'), ('pane', 'NN'), (',', ','), ('extended', 'VBD'), ('it', 'PRP'), ('over', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('tank', 'NN'), ('and', 'CC'), ('lowered', 'VBD'), ('the', 'DT'), ('hooks', 'NNS'), ('.', '.')], senses=('cord',))
# True label: cord, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=23, context=[('perfect', 'JJ'), (',', ','), ('mr', 'NNP'), ('.', '.'), ('ailes', 'NNP'), ('told', 'VBD'), ('him', 'PRP'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('president', 'NN'), ('suddenly', 'RB'), ('seemed', 'VBD'), ('to', 'TO'), ('grow', 'VB'), ('in', 'IN'), ('self-confidence', 'NN'), ('.', '.'), ('mr', 'NNP'), ('.', '.'), ('reagan', 'NNP'), ('used', 'VBD'), ('the', 'DT'), ('line', 'NN'), (',', ','), ('and', 'CC'), ('it', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('zinger', 'NN'), ('.', '.')], senses=('text',))
# True label: text, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=45, context=[('mr', 'NNP'), ('.', '.'), ('mcpherson', 'NNP'), ('and', 'CC'), ('arms', 'NNS'), ('negotiator', 'NN'), ('paul', 'NNP'), ('warnke', 'NNP'), ('both', 'DT'), ('remember', 'VB'), ('what', 'WP'), ('happened', 'VBD'), ('when', 'WRB'), ('president', 'NNP'), ('johnson', 'NNP'), ('tried', 'VBD'), ('to', 'TO'), ('reach', 'VB'), ('mr', 'NNP'), ('.', '.'), ('warnke', 'NNP'), ('to', 'TO'), ('offer', 'VB'), ('him', 'PRP'), ('a', 'DT'), ('pentagon', 'NNP'), ('promotion', 'NN'), ('.', '.'), ('the', 'DT'), ('president', 'NN'), ('talked', 'VBD'), ('for', 'IN'), ('five', 'CD'), ('minutes', 'NNS'), ('before', 'IN'), ('realizing', 'VBG'), ('that', 'IN'), ('the', 'DT'), ('man', 'NN'), ('on', 'IN'), ('the', 'DT'), ('other', 'JJ'), ('end', 'NN'), ('of', 'IN'), ('the', 'DT'), ('line', 'NN'), ('was', 'VBD'), ('john', 'NNP'), ('carl', 'NNP'), ('warnecke', 'NNP'), (',', ','), ('the', 'DT'), ('architect', 'NN'), ('.', '.')], senses=('phone',))
# True label: phone, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=39, context=[('another', 'DT'), (',', ','), ('the', 'DT'), ('most', 'RBS'), ('famous', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('charter', 'NN'), ('fleets', 'NNS'), (',', ','), ('is', 'VBZ'), ('at', 'IN'), ('kailua-kona', 'NNP'), (',', ','), ('near', 'IN'), ('the', 'DT'), ('famous', 'JJ'), ('marlin', 'NN'), ('grounds', 'NNS'), ('off', 'IN'), ('the', 'DT'), ('kona', 'NNP'), ('coast', 'NN'), ('.', '.'), ('the', 'DT'), ('skipper', 'NN'), ('and', 'CC'), ('crew', 'NN'), ('pilot', 'NN'), ('the', 'DT'), ('boat', 'NN'), (',', ','), ('provide', 'VB'), ('the', 'DT'), ('gear', 'NN'), (',', ','), ('and', 'CC'), ('bait', 'VB'), ('the', 'DT'), ('lines', 'NNS'), ('.', '.')], senses=('cord',))
# True label: cord, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=27, context=[('thus', 'RB'), (',', ','), ('some', 'DT'), ('families', 'NNS'), ('are', 'VBP'), ('probably', 'RB'), ('buying', 'VBG'), ('take-out', 'NN'), ('food', 'NN'), ('from', 'IN'), ('grocery', 'NN'), ('stores', 'NNS'), ('--', ':'), ('such', 'JJ'), ('as', 'IN'), ('barbecued', 'VBN'), ('chicken', 'NN'), ('--', ':'), ('but', 'CC'), ('aren', 'VBN'), ("'t", 'NN'), ('classifying', 'VBG'), ('it', 'PRP'), ('as', 'IN'), ('such', 'JJ'), ('.', '.'), ('the', 'DT'), ('line', 'NN'), ('between', 'IN'), ('groceries', 'NNS'), ('and', 'CC'), ('take-out', 'NN'), ('food', 'NN'), ('may', 'MD'), ('have', 'VB'), ('become', 'VBN'), ('blurred', 'VBN'), ('.', '.')], senses=('division',))
# True label: division, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=5, context=[('you', 'PRP'), ('quoted', 'VBD'), ('ford', 'NNP'), ("'s", 'POS'), ('old', 'JJ'), ('line', 'NN'), ('that', 'IN'), ('the', 'DT'), ('edsel', 'NNP'), ('was', 'VBD'), ('the', 'DT'), ('first', 'JJ'), ('"', '"'), ('all-new', 'JJ'), ('"', '"'), ('car', 'NN'), ('from', 'IN'), ('detroit', 'NNP'), ("'s", 'POS'), ('big', 'NNP'), ('three', 'CD'), ('in', 'IN'), ('18', 'CD'), ('years', 'NNS'), ('and', 'CC'), ('that', 'IN'), ('ford', 'NNP'), ('spent', 'VBD'), ('$', '$'), ('250', 'CD'), ('million', 'CD'), ('to', 'TO'), ('develop', 'VB'), ('it', 'PRP'), ('(', '('), ('ford', 'NNP'), ("'s", 'POS'), ('propaganda', 'NN'), ('always', 'RB'), ('said', 'VBD'), ('a', 'DT'), ('quarter', 'NN'), ('of', 'IN'), ('a', 'DT'), ('billion', 'CD'), ('--', ':'), ('it', 'PRP'), ('sounded', 'VBD'), ('bigger', 'JJR'), ('that', 'DT'), ('way', 'NN'), (')', 'SYM'), ('.', '.')], senses=('text',))
# True label: text, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=54, context=[('the', 'DT'), ('texts', 'NNS'), ('are', 'VBP'), ('often', 'RB'), ('shortened', 'VBN'), ('to', 'TO'), ('make', 'VB'), ('the', 'DT'), ('books', 'NNS'), ('cheaper', 'JJR'), ('to', 'TO'), ('produce', 'VB'), (',', ','), ('leaving', 'VBG'), ('a', 'DT'), ('skeleton', 'NN'), ('of', 'IN'), ('the', 'DT'), ('original', 'JJ'), ('story', 'NN'), ('.', '.'), ('mr', 'NNP'), ('.', '.'), ('lang', 'NNP'), ('notes', 'NNS'), ('that', 'IN'), ('there', 'RB'), ('are', 'VBP'), ('at', 'IN'), ('least', 'JJS'), ('10', 'CD'), ('heavily', 'RB'), ('illustrated', 'VBN'), ('editions', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('snow', 'NNP'), ('white', 'NNP'), ('story', 'NN'), ('in', 'IN'), ('which', 'WDT'), ('the', 'DT'), ('whole', 'JJ'), ('tale', 'NN'), ('is', 'VBZ'), ('told', 'VBN'), ('in', 'IN'), ('12', 'CD'), ('pages', 'NNS'), (',', ','), ('with', 'IN'), ('only', 'RB'), ('a', 'DT'), ('few', 'JJ'), ('lines', 'NNS'), ('on', 'IN'), ('each', 'DT'), ('.', '.')], senses=('text',))
# True label: text, Predicted label: product
# -------------------
# Test instance:
# SensevalInstance(word='line-n', position=25, context=[('amid', 'IN'), ('all', 'DT'), ('her', 'PRP$'), ('parenting', 'NN'), ('responsibilities', 'NNS'), (',', ','), ('she', 'PRP'), ('couldn', 'VBP'), ("'t", 'VBG'), ('fit', 'NN'), ('in', 'IN'), ('40', 'CD'), ('hours', 'NNS'), ('of', 'IN'), ('work', 'NN'), ('a', 'DT'), ('week', 'NN'), ('.', '.'), ('"', '"'), ('i', 'PRP'), ('couldn', 'VBP'), ("'t", 'VBG'), ('draw', 'NN'), ('a', 'DT'), ('definite', 'JJ'), ('line', 'NN'), ('--', ':'), ('i', 'PRP'), ("'d", 'MD'), ('drop', 'VB'), ('everything', 'NN'), ('for', 'IN'), ('my', 'PRP$'), ('children', 'NNS'), (',', ','), ('"', '"'), ('recalls', 'VBZ'), ('mrs', 'NNP'), ('.', '.'), ('schuldt', 'NNP'), (',', ','), ('who', 'WP'), ('has', 'VBZ'), ('returned', 'VBN'), ('to', 'TO'), ('work', 'VB'), ('at', 'IN'), ('the', 'DT'), ('factory', 'NN'), (',', ','), ('part-time', 'JJ'), ('.', '.')], senses=('division',))
# True label: division, Predicted label: product
# -------------------

# %%
model('hard.pos')
# Out:
# === Validation ===
# Window size     Vocabulary size Validation Accuracy
# =============================================
# 1               100             0.8750
# 1               200             0.8889
# 1               300             0.9074
# 2               100             0.8565
# 2               200             0.8657
# 2               300             0.8750
# 3               100             0.8611
# 3               200             0.8796
# 3               300             0.8935
# 4               100             0.8519
# 4               200             0.8704
# 4               300             0.8796
#
# Best parameters - Window size: 1, Vocabulary size: 300
#
# === Testing ===
# Accuracy: 0.8755
#
# Confusion matrix:
# [[872   5   1]
#  [ 54  71   0]
#  [ 75   0   6]]
#
# Examples of errors:
# ===================
# Test instance:
# SensevalInstance(word='hard-a', position=1, context=[('but', 'CC'), ('hard', 'JJ'), ('sided', 'VBD'), ('luggage', 'NN'), (',', ','), ('he', 'PRP'), ('says', 'VBZ'), (',', ','), ('is', 'VBZ'), ('the', 'DT'), ('elegant', 'JJ'), ('type', 'NN'), ('that', 'IN'), ('people', 'NNS'), ('carried', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('1920s', 'CD'), ('and', 'CC'), ('1930s', 'CD'), ('.', '.')], senses=('HARD3',))
# True label: HARD3, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=2, context=[('bumpy', 'NNP'), (',', ','), ('hard', 'JJ'), ('skinned', 'VBN'), (',', ','), ('irregularly', 'RB'), ('shaped', 'VBN'), ('squash', 'NN'), ('typifies', 'VBZ'), ('american', 'JJ'), ('fall', 'NN'), ('and', 'CC'), ('winter', 'NN'), ('harvest', 'NN'), ('food', 'NN'), ('at', 'IN'), ('its', 'PRP$'), ('best', 'JJS'), ('.', '.')], senses=('HARD3',))
# True label: HARD3, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=18, context=[('that', 'DT'), ('includes', 'VBZ'), ('sprint-boat', 'JJ'), ('racing', 'NN'), ('(', '('), ('whatever', 'WDT'), ('that', 'WDT'), ('is', 'VBZ'), (')', 'SYM'), (',', ','), ('as', 'IN'), ('mike', 'NNP'), ('woodger', 'NNP'), ('and', 'CC'), ('chris', 'NNP'), ('paddon', 'NNP'), ('learned', 'VBD'), ('the', 'DT'), ('hard', 'JJ'), ('way', 'NN'), ('in', 'IN'), ('melbourne', 'NNP'), (',', ','), ('although', 'IN'), ('neither', 'DT'), ('was', 'VBD'), ('injured', 'VBN'), ('when', 'WRB'), ('the', 'DT'), ('400-horsepower', 'JJ'), ('boat', 'NN'), ('hit', 'VBD'), ('an', 'DT'), ('embankment', 'NN'), ('.', '.')], senses=('HARD2',))
# True label: HARD2, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=2, context=[('early', 'RB'), (',', ','), ('hard', 'JJ'), ('domes', 'NNS'), ('necessitated', 'VBD'), ('round', 'NN'), ('stadiums', 'NNS'), ('for', 'IN'), ('support', 'NN'), ('--', ':'), ('an', 'DT'), ('inconvenient', 'JJ'), ('shape', 'NN'), ('for', 'IN'), ('both', 'DT'), ('baseball', 'NN'), ('and', 'CC'), ('football', 'NN'), ('.', '.')], senses=('HARD3',))
# True label: HARD3, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=17, context=[('the', 'DT'), ('hulking', 'JJ'), (',', ','), ('bald', 'JJ'), ('foreman', 'NNP'), ('whom', 'WP'), ('the', 'DT'), ('folks', 'NNS'), ('saw', 'VBD'), ('fight', 'NN'), ('qawi', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('different', 'JJ'), ('fella', 'NN'), ('from', 'IN'), ('the', 'DT'), ('hard', 'JJ'), ('muscled', 'VBD'), ('young', 'JJ'), ('champ', 'NN'), ('whose', 'WP$'), ('place', 'NN'), ('in', 'IN'), ('history', 'NN'), ('rests', 'VBZ'), ('largely', 'RB'), ('on', 'IN'), ('two', 'CD'), ('fights', 'NNS'), (',', ','), ('one', 'CD'), ('that', 'IN'), ('he', 'PRP'), ('won', 'VBD'), ('and', 'CC'), ('one', 'CD'), ('he', 'PRP'), ('lost', 'VBD'), ('.', '.')], senses=('HARD3',))
# True label: HARD3, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=12, context=[('surface', 'NN'), ('key', 'JJ'), (':', ':'), ('frm', 'NN'), ('pkd', 'NN'), ('=', 'SYM'), ('firm', 'NN'), ('packed', 'VBN'), (',', ','), ('hrd', 'NN'), ('pkd', 'NN'), ('=', 'SYM'), ('hard', 'JJ'), ('packed', 'VBN'), (',', ','), ('mch', 'NN'), ('grm', 'NN'), ('=', 'SYM'), ('machine', 'NN'), ('groomed', 'VBN'), (',', ','), ('pkd', 'NN'), ('pwdr', 'NN'), ('=', 'SYM'), ('packed', 'VBN'), ('powder', 'NN'), (',', ','), ('pwdr', 'NN'), ('=', 'SYM'), ('powder', 'NN'), ('.', '.')], senses=('HARD3',))
# True label: HARD3, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=6, context=[('my', 'PRP$'), ('pre-monkees', 'NNS'), ('singing', 'VBG'), ('had', 'VBN'), ('a', 'DT'), ('little', 'JJ'), ('harder', 'JJ'), ('edge', 'NN'), ('.', '.')], senses=('HARD2',))
# True label: HARD2, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=10, context=[('as', 'IN'), ('the', 'DT'), ('name', 'NN'), ('suggests', 'VBZ'), (',', ','), ('a', 'DT'), ('green', 'JJ'), ('plantain', 'NN'), ('has', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('bright', 'JJ'), ('green', 'JJ'), ('skin', 'NN'), ('.', '.')], senses=('HARD3',))
# True label: HARD3, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=7, context=[('they', 'PRP'), ('possessed', 'VBD'), ('no', 'DT'), ('outer', 'JJ'), ('fortifications', 'NNS'), (',', ','), ('no', 'DT'), ('hard', 'JJ'), ('shells', 'NNS'), ('of', 'IN'), ('confidence', 'NN'), (';', ':'), ('they', 'PRP'), ('had', 'VBD'), ('enough', 'JJ'), ('difficulty', 'NN'), ('getting', 'VBG'), ('from', 'IN'), ('day', 'NN'), ('to', 'TO'), ('day', 'NN'), (',', ','), ('let', 'VB'), ('alone', 'RB'), ('having', 'VBG'), ('an', 'DT'), ('awful', 'JJ'), ('crime', 'NN'), ('thrust', 'NN'), ('upon', 'IN'), ('them', 'PRP'), ('.', '.')], senses=('HARD3',))
# True label: HARD3, Predicted label: HARD1
# -------------------
# Test instance:
# SensevalInstance(word='hard-a', position=12, context=[('not', 'RB'), ('only', 'RB'), ('do', 'VB'), ('we', 'PRP'), ('remember', 'VB'), ('them', 'PRP'), ('for', 'IN'), ('their', 'PRP$'), ('great', 'JJ'), ('accomplishments', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('working', 'NN'), ('lifetime', 'NN'), ('but', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('that', 'IN'), ('they', 'PRP'), ('handed', 'VBD'), ('on', 'IN'), ('their', 'PRP$'), ('knowledge', 'NN'), ('to', 'TO'), ('others', 'NNS'), ('.', '.')], senses=('HARD2',))
# True label: HARD2, Predicted label: HARD1
# -------------------

# %%
model('serve.pos')
# Out:
# === Validation ===
# Window size     Vocabulary size Validation Accuracy
# =============================================
# 1               100             0.4612
# 1               200             0.4703
# 1               300             0.4703
# 2               100             0.5297
# 2               200             0.5616
# 2               300             0.5708
# 3               100             0.5890
# 3               200             0.6073
# 3               300             0.6347
# 4               100             0.6393
# 4               200             0.6712
# 4               300             0.7078
#
# Best parameters - Window size: 4, Vocabulary size: 300
#
# === Testing ===
# Accuracy: 0.6393
#
# Confusion matrix:
# [[437  19   0   1]
#  [127 196   3   1]
#  [125  26  57   2]
#  [ 58  32   1  10]]
#
# Examples of errors:
# ===================
# Test instance:
# SensevalInstance(word='serve-v', position=19, context=[('his', 'PRP$'), ('son', 'NN'), ('had', 'VBD'), ('entered', 'VBN'), ('the', 'DT'), ('army', 'NN'), (':', ':'), ('and', 'CC'), ('young', 'JJ'), ('osborne', 'NNP'), ('followed', 'VBD'), ('presently', 'RB'), ('in', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('regiment', 'NN'), ('.', '.'), ('they', 'PRP'), ('had', 'VBD'), ('served', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('west', 'NNP'), ('indies', 'NNPS'), ('and', 'CC'), ('in', 'IN'), ('canada', 'NNP'), ('.', '.')], senses=('SERVE12',))
# True label: SERVE12, Predicted label: SERVE10
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=47, context=[('he', 'PRP'), ('was', 'VBD'), ('an', 'DT'), ('early', 'JJ'), ('and', 'CC'), ('vigorous', 'JJ'), ('critic', 'NN'), ('of', 'IN'), ('the', 'DT'), ('court-packing', 'JJ'), ('plan', 'NN'), (',', ','), ('and', 'CC'), ('finally', 'RB'), ('with', 'IN'), ('the', 'DT'), ('coming', 'NN'), ('of', 'IN'), ('world', 'NNP'), ('war', 'NNP'), ('ii', 'NNP'), (',', ','), ('he', 'PRP'), ('fought', 'VBD'), ('the', 'DT'), ('president', 'NNP'), ('on', 'IN'), ('the', 'DT'), ('repeal', 'NN'), ('of', 'IN'), ('the', 'DT'), ('arms', 'NNP'), ('embargo', 'NNP'), ('and', 'CC'), ('opposed', 'VBN'), ('u', 'NNP'), ('.', '.'), ('s', 'NNP'), ('.', '.'), ('efforts', 'NNS'), ('to', 'TO'), ('rearm', 'VB'), ('the', 'DT'), ('allies', 'NNPS'), ('.', '.'), ('senator', 'NNP'), ('wheeler', 'NNP'), ('served', 'VBD'), ('continually', 'RB'), ('in', 'IN'), ('the', 'DT'), ('united', 'NNP'), ('states', 'NNP'), ('senate', 'NNP'), ('from', 'IN'), ('1928', 'CD'), ('to', 'TO'), ('1947', 'CD'), ('.', '.')], senses=('SERVE12',))
# True label: SERVE12, Predicted label: SERVE10
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=86, context=[('there', 'EX'), ('were', 'VBD'), ('dirty', 'JJ'), ('trays', 'NNS'), (',', ','), ('and', 'CC'), ('wine-coolers', 'NNS'), ('en', 'IN'), ('permanence', 'NN'), ('on', 'IN'), ('the', 'DT'), ('sideboard', 'NN'), (',', ','), ('huge', 'JJ'), ('dirty', 'JJ'), ('gilt', 'JJ'), ('cornices', 'NNS'), (',', ','), ('with', 'IN'), ('dingy', 'JJ'), ('yellow', 'JJ'), ('satin', 'NN'), ('hangings', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('barred', 'VBN'), ('windows', 'NNS'), ('which', 'WDT'), ('looked', 'VBD'), ('into', 'IN'), ('cursitor', 'NNP'), ('street', 'NNP'), ('vast', 'JJ'), ('and', 'CC'), ('dirty', 'JJ'), ('gilt', 'JJ'), ('picture-frames', 'NNS'), ('surrounding', 'VBG'), ('pieces', 'NNS'), ('sporting', 'VBG'), ('and', 'CC'), ('sacred', 'JJ'), (',', ','), ('all', 'DT'), ('of', 'IN'), ('which', 'WDT'), ('works', 'NNS'), ('were', 'VBD'), ('by', 'IN'), ('the', 'DT'), ('greatest', 'JJS'), ('masters', 'NNS'), (';', ':'), ('and', 'CC'), ('fetched', 'VBD'), ('the', 'DT'), ('greatest', 'JJS'), ('prices', 'NNS'), (',', ','), ('too', 'RB'), (',', ','), ('in', 'IN'), ('the', 'DT'), ('bill', 'NN'), ('transactions', 'NNS'), (',', ','), ('in', 'IN'), ('the', 'DT'), ('course', 'NN'), ('of', 'IN'), ('which', 'WDT'), ('they', 'PRP'), ('were', 'VBD'), ('sold', 'VBN'), ('and', 'CC'), ('bought', 'VBD'), ('over', 'IN'), ('and', 'CC'), ('over', 'IN'), ('again', 'RB'), ('.', '.'), ('the', 'DT'), ('colonel', 'NNP'), ("'s", 'POS'), ('breakfast', 'NN'), ('was', 'VBD'), ('served', 'VBD'), ('to', 'TO'), ('him', 'PRP'), ('in', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('dingy', 'JJ'), ('and', 'CC'), ('gorgeous', 'JJ'), ('plated', 'VBN'), ('ware', 'NN'), ('.', '.')], senses=('SERVE10',))
# True label: SERVE10, Predicted label: SERVE12
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=25, context=[('the', 'DT'), ('ladies', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('french', 'JJ'), ('society', 'NN'), (',', ','), ('in', 'IN'), ('time', 'NN'), ('of', 'IN'), ('trouble', 'NN'), (',', ','), ('headed', 'VBN'), ('straight', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('pentemont', 'NNP'), ('.', '.'), ('as', 'IN'), ('things', 'NNS'), ('turned', 'VBD'), ('out', 'IN'), (',', ','), ('it', 'PRP'), ('served', 'VBD'), ('rose', 'NNP'), ('as', 'IN'), ('a', 'DT'), ('finishing', 'VBG'), ('school', 'NN'), ('.', '.')], senses=('SERVE2',))
# True label: SERVE2, Predicted label: SERVE10
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=18, context=[('no', 'DT'), ('more', 'JJR'), ('.', '.'), ('distressed', 'JJ'), ('by', 'IN'), ('the', 'DT'), ('escalating', 'VBG'), ('costs', 'NNS'), ('of', 'IN'), ('medical', 'JJ'), ('care', 'NN'), (',', ','), ('businesses', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('insurance', 'NN'), ('companies', 'NNS'), ('that', 'WDT'), ('serve', 'VB'), ('them', 'PRP'), ('are', 'VBP'), ('beginning', 'VBG'), ('to', 'TO'), ('shuck', 'VB'), ('the', 'DT'), ('role', 'NN'), ('of', 'IN'), ('passive', 'JJ'), ('bill-payer', 'NN'), ('.', '.')], senses=('SERVE6',))
# True label: SERVE6, Predicted label: SERVE12
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=61, context=[('the', 'DT'), ('group', 'NN'), ('opposes', 'VBZ'), ('current', 'JJ'), ('management', 'NN'), (',', ','), ('he', 'PRP'), ('said', 'VBD'), (',', ','), ('because', 'IN'), ('pay-fone', 'NNP'), ("'s", 'POS'), ('results', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('"', '"'), ('inadequate', 'JJ'), ('in', 'IN'), ('terms', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('revenue', 'NN'), ('flatness', 'NN'), ('that', 'WDT'), ('has', 'VBZ'), ('persisted', 'VBN'), ('at', 'IN'), ('the', 'DT'), ('company', 'NN'), ('.', '.'), ('"', '"'), ('responding', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('kahn', 'NNP'), ('group', 'NN'), ("'s", 'POS'), ('proxy', 'NN'), ('material', 'NN'), (',', ','), ('pay-fone', 'NNP'), ('issued', 'VBD'), ('a', 'DT'), ('shareholder', 'NN'), ('letter', 'NN'), ('saying', 'VBG'), ('that', 'IN'), ('"', '"'), ('the', 'DT'), ('kahn', 'NNP'), ('slate', 'NN'), ('has', 'VBZ'), ('neither', 'DT'), ('the', 'DT'), ('experience', 'NN'), ('nor', 'CC'), ('the', 'DT'), ('qualifications', 'NNS'), ('necessary', 'JJ'), ('"', '"'), ('to', 'TO'), ('serve', 'VB'), ('as', 'IN'), ('directors', 'NNS'), ('.', '.')], senses=('SERVE12',))
# True label: SERVE12, Predicted label: SERVE10
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=23, context=[('these', 'DT'), ('findings', 'NNS'), ('are', 'VBP'), ('consistent', 'JJ'), ('with', 'IN'), ('the', 'DT'), ('original', 'JJ'), ('plans', 'NNS'), ('and', 'CC'), ('expectations', 'NNS'), ('for', 'IN'), ('eces', 'NNS'), ('.', '.'), ('the', 'DT'), ('system', 'NN'), ('was', 'VBD'), ('designed', 'VBN'), ('to', 'TO'), ('complement', 'VB'), ('guidance', 'NN'), ('programs', 'NNS'), ('and', 'CC'), ('to', 'TO'), ('serve', 'VB'), ('as', 'IN'), ('an', 'DT'), ('aid', 'NN'), ('to', 'TO'), ('counselors', 'NNS'), (',', ','), ('to', 'TO'), ('help', 'VB'), ('them', 'PRP'), ('work', 'VB'), ('more', 'RBR'), ('effectively', 'RB'), ('with', 'IN'), ('their', 'PRP$'), ('students', 'NNS'), ('by', 'IN'), ('helping', 'VBG'), ('students', 'NNS'), ('become', 'VBP'), ('better', 'RBR'), ('informed', 'VBN'), ('.', '.')], senses=('SERVE2',))
# True label: SERVE2, Predicted label: SERVE10
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=57, context=[('lawrence', 'NNP'), ('k', 'NNP'), ('.', '.'), ('altman', 'NNP'), ('in', 'IN'), ('new', 'NNP'), ('york', 'NNP'), ('times', 'NNP'), ('if', 'IN'), ('the', 'DT'), ('kids', 'NNS'), ('can', 'MD'), ("'t", 'VB'), ('go', 'NN'), ('to', 'TO'), ('the', 'DT'), ('dentist', 'NN'), (',', ','), ('then', 'RB'), ('the', 'DT'), ('dentist', 'NN'), ('must', 'MD'), ('come', 'VB'), ('to', 'TO'), ('the', 'DT'), ('kids', 'NNS'), ('.', '.'), ('that', 'DT'), ("'s", 'VBZ'), ('the', 'DT'), ('philosophy', 'NN'), ('behind', 'IN'), ('the', 'DT'), ('"', '"'), ('smilemobile', 'NNP'), ('"', '"'), ('a', 'DT'), ('40-foot', 'NNP'), ('van', 'NNP'), ('run', 'VB'), ('by', 'IN'), ('the', 'DT'), ('nonprofit', 'JJ'), ('children', 'NNS'), ("'s", 'POS'), ('dental', 'NNP'), ('health', 'NNP'), ('service', 'NNP'), ('in', 'IN'), ('rochester', 'NNP'), (',', ','), ('n', 'NN'), ('.', '.'), ('y', 'NNP'), ('.', '.'), (',', ','), ('which', 'WDT'), ('serves', 'VBZ'), ('nearly', 'RB'), ('1000', 'CD'), ('inner-city', 'JJ'), ('youngsters', 'NNS'), ('.', '.')], senses=('SERVE6',))
# True label: SERVE6, Predicted label: SERVE10
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=54, context=[('it', 'PRP'), ('produces', 'VBZ'), ('tv', 'NN'), ('programs', 'NNS'), ('about', 'IN'), ('nuclear', 'JJ'), ('proliferation', 'NN'), (',', ','), ('population', 'NN'), ('control', 'NN'), ('and', 'CC'), ('the', 'DT'), ('environment', 'NN'), (',', ','), ('and', 'CC'), ('it', 'PRP'), ('allows', 'VBZ'), ('mr', 'NNP'), ('.', '.'), ('turner', 'NNP'), ('to', 'TO'), ('attend', 'VB'), ('board', 'NN'), ('meetings', 'NNS'), ('with', 'IN'), ('jimmy', 'NNP'), ('carter', 'NNP'), ('and', 'CC'), ('jacques', 'NNP'), ('cousteau', 'NNP'), ("'s", 'POS'), ('son', 'NN'), ('.', '.'), ('it', 'PRP'), ('also', 'RB'), ('interests', 'VBZ'), ('mr', 'NNP'), ('.', '.'), ('turner', 'NNP'), ("'s", 'POS'), ('former', 'JJ'), ('pilot', 'NN'), ('and', 'CC'), ('current', 'JJ'), ('female', 'JJ'), ('companion', 'NN'), (',', ','), ('j', 'NNP'), ('.', '.'), ('j', 'NNP'), ('.', '.'), ('ebaugh', 'NNP'), (',', ','), ('who', 'WP'), ('serves', 'VBZ'), ('as', 'IN'), ('a', 'DT'), ('liaison', 'NN'), ('between', 'IN'), ('the', 'DT'), ('society', 'NN'), ('and', 'CC'), ('turner', 'NNP'), ('broadcasting', 'NNP'), ('.', '.')], senses=('SERVE12',))
# True label: SERVE12, Predicted label: SERVE10
# -------------------
# Test instance:
# SensevalInstance(word='serve-v', position=27, context=[('sometimes', 'RB'), ('this', 'DT'), ('testing', 'NN'), ('can', 'MD'), ('get', 'VB'), ('pretty', 'RB'), ('sticky', 'JJ'), ('.', '.'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('much', 'RB'), ('easier', 'JJR'), ('to', 'TO'), ('describe', 'VB'), ('this', 'DT'), (',', ','), ('for', 'IN'), ('instance', 'NN'), (',', ','), ('if', 'IN'), ('each', 'DT'), ('participant', 'NN'), ('could', 'MD'), ('have', 'VB'), ('simply', 'RB'), ('been', 'VBN'), ('served', 'VBD'), ('three', 'CD'), ('cups', 'NNS'), (',', ','), ('each', 'DT'), ('containing', 'VBG'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('three', 'CD'), ('choices', 'NNS'), ('.', '.')], senses=('SERVE10',))
# True label: SERVE10, Predicted label: SERVE12
# -------------------

# %%
model('interest.pos')
# Out:
# === Validation ===
# Window size     Vocabulary size Validation Accuracy
# =============================================
# 1               100             0.5042
# 1               200             0.5294
# 1               300             0.5462
# 2               100             0.5546
# 2               200             0.5966
# 2               300             0.6134
# 3               100             0.5546
# 3               200             0.5966
# 3               300             0.6134
# 4               100             0.5042
# 4               200             0.5462
# 4               300             0.5546
#
# Best parameters - Window size: 2, Vocabulary size: 300
#
# === Testing ===
# Accuracy: 0.6791
#
# Confusion matrix:
# [[ 23   0   0   1   1  78]
#  [  0   0   0   0   0   2]
#  [  0   0   0   0   0  17]
#  [  0   0   0   7   0  36]
#  [  0   0   0   0  63  54]
#  [  0   0   0   0   1 309]]
#
# Examples of errors:
# ===================
# Test instance:
# SensevalInstance(word='interest-n', position=11, context=[('the', 'DT'), ('meeting', 'NN'), ('offered', 'VBD'), ('stark', 'JJ'), ('evidence', 'NN'), ('of', 'IN'), ('a', 'DT'), ('dramatic', 'JJ'), ('fall', 'NN'), ('in', 'IN'), ('scientific', 'JJ'), ('interest', 'NN'), ('in', 'IN'), ('cold', 'JJ'), ('fusion', 'NN'), ('research', 'NN'), ('.', '.')], senses=('interest_1',))
# True label: interest_1, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=15, context=[('on', 'IN'), ('the', 'DT'), ('contrary', 'NN'), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('too', 'RB'), ('responsive', 'JJ'), ('to', 'TO'), ('an', 'DT'), ('incorrect', 'JJ'), ('view', 'NN'), ('of', 'IN'), ('the', 'DT'), ('public', 'JJ'), ('interest', 'NN'), ('.', '.')], senses=('interest_4',))
# True label: interest_4, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=14, context=[('``', '``'), ('we', 'PRP'), ('will', 'MD'), ('vote', 'VB'), ('our', 'PRP$'), ('claims', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('way', 'NN'), ('that', 'IN'), ('suits', 'NNS'), ('our', 'PRP$'), ('customers', 'NNS'), ("'", 'POS'), ('interests', 'NNS'), (',', ','), ("''", "''"), ('he', 'PRP'), ('says', 'VBZ'), ('.', '.')], senses=('interest_4',))
# True label: interest_4, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=9, context=[('the', 'DT'), ('commission', 'NN'), ('said', 'VBD'), ('coats', 'NNS'), ('must', 'MD'), ('first', 'RB'), ('dispose', 'VB'), ('of', 'IN'), ('its', 'PRP$'), ('interest', 'NN'), ('in', 'IN'), ('britain', 'NN'), ("'s", 'POS'), ('domestic', 'JJ'), ('sewing', 'NN'), ('thread', 'NN'), ('industry', 'NN'), ('and', 'CC'), ('its', 'PRP$'), ('shares', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('gutermann', 'NN'), ('group', 'NN'), ('.', '.')], senses=('interest_5',))
# True label: interest_5, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=13, context=[('panhandle', 'NN'), ('said', 'VBD'), ('the', 'DT'), ('long-depressed', 'JJ'), ('houston', 'NN'), ('market', 'NN'), ('improved', 'VBN'), ('enough', 'RB'), ('this', 'DT'), ('year', 'NN'), ('to', 'TO'), ('generate', 'VB'), ('more', 'JJR'), ('interest', 'NN'), ('than', 'IN'), ('anticipated', 'VBN'), ('.', '.')], senses=('interest_1',))
# True label: interest_1, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=4, context=[('they', 'PRP'), ('were', 'VBD'), ('protecting', 'VBG'), ('his', 'PRP$'), ('interests', 'NNS'), ('.', '.')], senses=('interest_4',))
# True label: interest_4, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=7, context=[('an', 'DT'), ('official', 'NN'), ('said', 'VBD'), ('there', 'EX'), ('has', 'VBZ'), ('been', 'VBN'), ('much', 'JJ'), ('interest', 'NN'), ('in', 'IN'), ('the', 'DT'), ('company', 'NN'), ('recently', 'RB'), ('.', '.')], senses=('interest_1',))
# True label: interest_1, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=14, context=[('when', 'WRB'), ('international', 'JJ'), ('business', 'NN'), ('machines', 'NNS'), ('hit', 'VBD'), ('a', 'DT'), ('52-week', 'JJ'), ('low', 'NN'), ('on', 'IN'), ('tuesday', 'NN'), (',', ','), ('it', 'PRP'), ('stirred', 'VBD'), ('some', 'DT'), ('interest', 'NN'), ('among', 'IN'), ('bottom-fishers', 'NNS'), ('.', '.')], senses=('interest_1',))
# True label: interest_1, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=8, context=[('in', 'IN'), ('panama', 'NN'), (',', ','), ('the', 'DT'), ('u', 'PRP'), ('.', '.'), ('s', 'PRP'), ('.', '.'), ('interests', 'NNS'), ('at', 'IN'), ('stake', 'NN'), ('were', 'VBD'), ('happily', 'RB'), ('minor', 'JJ'), (';', ':'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('killed', 'VBN'), ('were', 'VBD'), ('foreigners', 'NNS'), ('hapless', 'JJ'), ('enough', 'RB'), ('to', 'TO'), ('trust', 'VB'), ('american', 'NN'), ('will', 'MD'), ('.', '.')], senses=('interest_4',))
# True label: interest_4, Predicted label: interest_6
# -------------------
# Test instance:
# SensevalInstance(word='interest-n', position=19, context=[('british', 'JJ'), ('plaster', 'NN'), ('board', 'NN'), ('closed', 'VBD'), ('at', 'IN'), ('255', 'CD'), (',', ','), ('up', 'IN'), ('15', 'CD'), (',', ','), ('on', 'IN'), ('new', 'JJ'), ('account', 'NN'), ('buying', 'VBG'), ('and', 'CC'), ('talk', 'VB'), ('of', 'IN'), ('possible', 'JJ'), ('takeover', 'NN'), ('interest', 'NN'), ('in', 'IN'), ('the', 'DT'), ('company', 'NN'), ('.', '.')], senses=('interest_1',))
# True label: interest_1, Predicted label: interest_6
# -------------------
